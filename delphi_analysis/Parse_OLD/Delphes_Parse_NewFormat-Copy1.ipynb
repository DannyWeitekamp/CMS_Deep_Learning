# %%
#WARNING THIS SCRIPT TAKES A LONG TIME TO RUN!
#Note Everythin is in natural units so C = 1
import sys, os
if __package__ is None:
    import sys, os
    sys.path.append(os.path.realpath("/data/shared/Software/"))
    sys.path.append(os.path.realpath("../../"))
from CMS_Deep_Learning.utils.data_parse import ROOT_to_pandas
from CMS_Deep_Learning.utils.data_parse import DataProcessingProcedure
from CMS_Deep_Learning.utils.data_parse import leaves_from_obj
import ROOT
from ROOT import TTree
import numpy as np
import pandas as pd
import ntpath
import glob
from itertools import cycle, islice

#didit = False
# Out:
# Welcome to ROOTaaS 6.06/04

# %%
def cullNonObservables(frame):
    #Status of 1 means that the particle is a stable product
    stable_cond = frame["Status"] == 1 
    #All even leptons are neutrinos which we can't measure
    notNeutrino_cond = frame["PID"] % 2 == 1
    parton_cond = np.abs(frame["PID"]) <= 8
    #Get all entries that satisfy the conditions
    frame = frame[stable_cond & notNeutrino_cond]
    #Drop the Status frame since we only needed it to see if the particle was stable
    frame = frame.drop(["Status"], axis=1)
    return frame

#Define the speed of light C
#Turns C=1 since everything is in natural units :/
#C = np.float64(2.99792458e8); #m/s
mass_of_electron = np.float64(0.0005109989461) #eV/c
mass_of_muon = np.float64(0.1056583715)      #eV/c
#def four_vec_func(inputs):
#        E = inputs[0]
#        Eta = inputs[1]
#        Phi = inputs[2]
#        PT = inputs[3]
#        E_over_c = E/C
#        px = E_over_c * np.sin(Phi) * np.cos(Eta) 
#        py = E_over_c * np.sin(Phi) * np.sin(Eta)
#        pz = E_over_c * np.cos(Phi)
#        print(np.sqrt(px*px + py*py), PT/C)
#        return [E_over_c, px, py, pz]

#def getPandasPhotons(filename):
#    four_vec_inputs, dummy = leaves_from_obj("Photon", ["PT", "Eta", "Phi"])
#    four_vec_proc = DataProcessingProcedure(lambda x: four_vec_from_PT(x,0), four_vec_inputs, ["E/c", "Px","Py","Pz"])

#    PID_proc = DataProcessingProcedure(lambda x:[22], [], ["PID"])
#    charge_proc = DataProcessingProcedure(lambda x:[0], [], ["Charge"])

#    columns=[four_vec_proc, PID_proc, charge_proc]
#    leaves, columns = leaves_from_obj("Photon", columns+["PT", "Eta", "Phi"])

#    photon_frame = ROOT_to_pandas(filename,
#                          leaves,
#                          columns=columns,
#                          verbosity=1)
#    return photon_frame


extra_data = ["PT", "Phi", "Eta"]
dxy_proc = [DataProcessingProcedure(lambda x: [0], [], ["Dxy"])]
elfow_proc = [DataProcessingProcedure(lambda x: [0,0], [], ["Eem", "Ehad"])]


def four_vec_from_PT(inputs, M):
    #print(type(inputs[0]))
    PT = inputs[0] #Units ?
    Eta = inputs[1]
    Phi = inputs[2]
    #M has units of eV/(c^2)
    if(M == None):
        M = inputs[3]
    momentum_mag = PT * np.cosh(Eta)
    #if(~didit):
    #print(momentum_mag, PT, np.cosh(Eta))
    #    didit = True
    E_over_c = np.sqrt(np.square(M) + np.square(momentum_mag))
    #print(PT/np.sin(Phi))
    px = PT * np.cos(Phi) 
    py = PT * np.sin(Phi) 
    pz = PT * np.sinh(Eta)
    return [E_over_c, px, py, pz]

def getPandasParticles(filename, cull=True):
    #C=1 in natural units so no processing needs to be done
    E_over_c_proc = DataProcessingProcedure(lambda x:x[0], ["Particle.E"], ["E/c"])
    columns= [E_over_c_proc, "Px", "Py", "Pz", "PID", "Charge"]#, "Status"]
    leaves, columns = leaves_from_obj("Particle", columns+extra_data + dxy_proc + elfow_proc)
    original_frame = ROOT_to_pandas(filename,
                                 leaves,
                                  columns=columns,
                                  verbosity=1)
    if(cull):
        particle_frame = cullNonObservables(original_frame)
    else:
        particle_frame = original_frame
    return particle_frame


def getPandasSpecificParticles(filename, name, mass=None, pid=None, chrg_def=-1, charge=None):
    if(mass != None):
        four_vec_inputs, dummy = leaves_from_obj(name, ["PT", "Eta", "Phi"])
    else:
        four_vec_inputs, dummy = leaves_from_obj(name, ["PT", "Eta", "Phi", "Mass"])
        
    four_vec_proc = DataProcessingProcedure(lambda x: four_vec_from_PT(x,mass)
                                            , four_vec_inputs, ["E/c", "Px","Py","Pz"])
    
    #status_proc = DataProcessingProcedure(lambda x:[1], [], ["Status"])
    
    if(charge == None):
        if(pid != None):
            PID_charge_proc = DataProcessingProcedure(lambda x: [pid*chrg_def*x[0], x[0]]
                                                      , [name + ".Charge"], ["PID", "Charge"])
            columns=[four_vec_proc, PID_charge_proc]#, status_proc]
        else:
            columns=[four_vec_proc, "PID", "Charge"]#, status_proc]
    else:
        charge_proc = DataProcessingProcedure(lambda x: [charge], [], ["Charge"])
        if(pid != None):
            PID_proc = DataProcessingProcedure(lambda x: [pid], [], ["PID"])
            columns=[four_vec_proc, PID_proc, charge_proc]#,status_proc]
        else:
            columns=[four_vec_proc, "PID", charge_proc]#,status_proc]
        
        
        
        
    
    leaves, columns = leaves_from_obj(name, columns+extra_data + dxy_proc + elfow_proc)

    #Extract the tables from the root file
    frame = ROOT_to_pandas(filename,
                          leaves,
                          columns=columns,
                          verbosity=1)
    return frame

def getPandasPhotons(filename):
    return getPandasSpecificParticles(filename, "Photon", mass=0, pid=22, charge=0)

def getPandasElectrons(filename):
    return getPandasSpecificParticles(filename, "Electron", mass=mass_of_electron, pid=11)

def getPandasTightMuons(filename):
    return getPandasSpecificParticles(filename, "MuonTight", mass=mass_of_muon, pid=13)

def getPandasJets(filename):
    return getPandasSpecificParticles(filename, "Jet", pid=100, chrg_def=1)

def getPandasMissingET(filename, name="MissingET"):  
    pid = 83
    if(name == "PuppiMissingET"): pid=84
    four_vec_inputs, dummy = leaves_from_obj(name, ["MET", "Eta", "Phi"])
    four_vec_proc = DataProcessingProcedure(lambda x: four_vec_from_PT(x,0)
                                            , four_vec_inputs, ["E/c", "Px","Py","Pz"])
    #status_proc = DataProcessingProcedure(lambda x:[1], [], ["Status"])
    charge_proc = DataProcessingProcedure(lambda x: [0], [], ["Charge"])
    PID_proc = DataProcessingProcedure(lambda x: [pid], [], ["PID"])
    columns=[four_vec_proc, PID_proc, charge_proc]#, status_proc]
    met_proc = DataProcessingProcedure(lambda x: [x[0]], ["MissingET.MET"], ["PT"] )
    
    ex = [x if (x != "PT") else met_proc for x in extra_data]
    leaves, columns = leaves_from_obj(name, columns+ex + dxy_proc + elfow_proc)

    #Extract the tables from the root file
    frame = ROOT_to_pandas(filename,
                          leaves,
                          columns=columns,
                          verbosity=1)
    return frame
def getPandasEFlowParticle(filename, name="EFlowPhoton"):  
    pid = 90
    if(name == "EFlowNeutralHadron"): pid=91
    four_vec_inputs, dummy = leaves_from_obj(name, ["ET", "Eta", "Phi"])
    four_vec_proc = DataProcessingProcedure(lambda x: four_vec_from_PT(x,0)
                                            , four_vec_inputs, ["E/c", "Px","Py","Pz"])
    #status_proc = DataProcessingProcedure(lambda x:[1], [], ["Status"])
    charge_proc = DataProcessingProcedure(lambda x: [0], [], ["Charge"])
    PID_proc = DataProcessingProcedure(lambda x: [pid], [], ["PID"])
    columns=[four_vec_proc, PID_proc, charge_proc]#, status_proc]
    
    
    et_proc = DataProcessingProcedure(lambda x: [x[0]], [name+".ET"], ["PT"] )
    
    ex = [x if (x != "PT") else et_proc for x in extra_data]
    leaves, columns = leaves_from_obj(name, columns+ex + dxy_proc + ["Eem", "Ehad"])

    #Extract the tables from the root file
    frame = ROOT_to_pandas(filename,
                          leaves,
                          columns=columns,
                          verbosity=1)
    return frame

def getPandasEFlowTrack(filename):  
    pid = 89
    four_vec_inputs, dummy = leaves_from_obj("EFlowTrack", ["PT", "Eta", "Phi"])
    four_vec_proc = DataProcessingProcedure(lambda x: four_vec_from_PT(x,0)
                                            , four_vec_inputs, ["E/c", "Px","Py","Pz"])
    #status_proc = DataProcessingProcedure(lambda x:[1], [], ["Status"])
    #charge_proc = DataProcessingProcedure(lambda x: [0], [], ["Charge"])
    PID_proc = DataProcessingProcedure(lambda x: [pid], [], ["PID"])
    columns=[four_vec_proc, PID_proc, "Charge"]#, status_proc]
    
    
    #et_proc = DataProcessingProcedure(lambda x: [x[0]], [name+".ET"], ["PT"] )
    
    #ex = [x if (x != "PT") else et_proc for x in extra_data]
    leaves, columns = leaves_from_obj("EFlowTrack", columns+extra_data + ["Dxy"] + elfow_proc)
    print(leaves, columns)
    #Extract the tables from the root file
    frame = ROOT_to_pandas(filename,
                          leaves,
                          columns=columns,
                          verbosity=1)
    return frame


#def getPandasAll(filename, cull=False, includePuppi=True):
#    lst = [getPandasPhotons(filename),
#                    getPandasElectrons(filename),
#                    getPandasTightMuons(filename),
#                    getPandasJets(filename),
#                    getPandasParticles(filename, cull=cull),
#                    getPandasMissingET(filename)]
#    
#    if(includePuppi):
#        lst = lst + [getPandasMissingET(filename, "PuppiMissingET")]
#    #Merge all these frames
#    out = pd.concat(lst)
#    return out

def getPandasAll(filename, cull=False, includePuppi=False):
    lst = [getPandasPhotons(filename),
                    getPandasElectrons(filename),
                    getPandasTightMuons(filename),
                    getPandasEFlowParticle(filename, name="EFlowNeutralHadron"),
                    getPandasEFlowParticle(filename, name="EFlowPhoton"),
                    getPandasEFlowTrack(filename),
                    getPandasMissingET(filename)]
    
    if(includePuppi):
        lst = lst + [getPandasMissingET(filename, "PuppiMissingET")]
    #Merge all these frames
    out = pd.concat(lst)
    return out

#def getPandasAll(filename):
#    out = pd.concat([getPandasPhotons(filename),getPandasParticles(filename, cull=False)])
#    return out

#http://stackoverflow.com/questions/3678869/pythonic-way-to-combine-two-lists-in-an-alternating-fashion
def roundrobin(*iterables):
    "roundrobin('ABC', 'D', 'EF') --> A D E B F C"
    # Recipe credited to George Sakkis
    pending = len(iterables)
    nexts = cycle(iter(it).next for it in iterables)
    while pending:
        try:
            for next in nexts:
                yield next()
        except StopIteration:
            pending -= 1
            nexts = cycle(islice(nexts, pending))

    
def storeAllUnjoined(filepath, outputDir, rerun=False):
    
    filename = os.path.splitext(ntpath.basename(filepath))[0]
    
    name_cols = [("EFlowTrack", ["PT", "Eta", "Phi", "Dxy", "Charge"]),
                 ("EFlowPhoton", ["ET", "Eta", "Phi", "Eem", "Ehad"]),
                 ("EFlowNeutralHadron", ["ET", "Eta", "Phi", "Eem", "Ehad"]),
                 ("Electron", ["PT", "Eta", "Phi", "Charge"]),
                 ("MuonTight", ["PT", "Eta", "Phi", "Charge"]),
                 ("MissingET", ["MET", "Eta", "Phi"])]
    for nc in name_cols:
        name = nc[0]
        cols = nc[1]
        out_file = outputDir + name + "/" + filename + ".h5"
        leaves, columns = leaves_from_obj(name,cols)
        if not os.path.exists(outputDir+name):
            os.makedirs(outputDir+name)
        if(rerun or os.path.isfile(out_file) == False):
            #print(rerun, ~os.path.isfile(out_file), out_file)
            frame = ROOT_to_pandas(filepath, leaves, columns=columns)
            frame.to_hdf(out_file, 'data', mode='w')

def storeAllJoined(filepath, outputfile, rerun=False):
    if(rerun or os.path.isfile(outputfile) == False):
        #print(rerun, ~os.path.isfile(out_file), out_file)
        frame = getPandasAll(filepath)
        frame.to_hdf(outputfile, 'data', mode='w')
    

    
def makeJobs(filename, job_types,
             directory="/data/shared/Delphes/",
             unjoined_folder="/pandas_unjoined/",
             joined_folder="/pandas_joined/"):
    files = glob.glob(directory + filename + "/*.root")
    unjoined_dir = directory + filename + unjoined_folder
    joined_dir = directory + filename + joined_folder
    if not os.path.exists(joined_dir):
        os.makedirs(joined_dir)
    
    jobs = []
    
    for f in files:
        f_name = os.path.splitext(ntpath.basename(f))[0]
        for j_type in job_types:
            if(j_type == "unjoined"):
                jobs.append((j_type,f, unjoined_dir))
            elif(j_type == "joined"):
                jobs.append((j_type,f, joined_dir + f_name + ".h5"))

    return jobs
    
    
#def groupEntriesToArrays(frame, select):
#    out = []
#    m = frame['Entry'].max()
#    for entry in range(0, m+1):
#        cond = frame['Entry'] == entry
#        entry_frame = frame[cond]
#        entry_frame = entry_frame[select]
#        arr = np.array(entry_frame)
#        np.random.shuffle(arr)
#        out.append(arr)
#    return out

#def groupEntriesToArrays(frame, select):
#    grouped = frame.groupby(["Entry"]).apply(lambda df: df[select].tolist())
    #print(grouped)
#    return grouped

# %%
ttbar_files = glob.glob("/data/shared/Delphes/ttbar_lepFilter_13TeV/*.root")
# WJet_files = glob.glob("/data/shared/Delphes/wjets_lepFilter_13TeV/*.root")
# WJet_files = glob.glob("/data/shared/Delphes/qcd_lepFilter_13TeV/*.root")

#frame = getPandasEFlowParticle(ttbar_files[0])
#print(frame)
#frame = getPandasEFlowParticle(ttbar_files[0], "EFlowNeutralHadron")
#print(frame)
#frame = getPandasEFlowTrack(ttbar_files[0])
#print(frame)
#frame = getPandasPhotons(ttbar_files[0])
#print(frame)
#frame = getPandasElectrons(ttbar_files[0])
#print(frame)
#frame = getPandasTightMuons(ttbar_files[0])
#print(frame)
#frame = getPandasMissingET(ttbar_files[0])
#print(frame)

ttbar_jobs = makeJobs("ttbar_lepFilter_13TeV", ["joined"])
WJet_jobs = makeJobs("wjets_lepFilter_13TeV", ["joined"])
qcd_jobs = makeJobs("qcd_lepFilter_13TeV", ["joined"])
#ttbar_jobs = makeJobs("ttbar_lepFilter_13TeV", ["unjoined"])
#WJet_jobs = makeJobs("wjets_lepFilter_13TeV", ["unjoined"])
#qcd_jobs = makeJobs("qcd_lepFilter_13TeV", ["unjoined"])
    
jobs = roundrobin(qcd_jobs)

# %%
from multiprocessing.dummy import Pool
# from multiprocessing import Process, Queue
# import time

def doJob(job):
    if(job[0] == "unjoined"):
        print("Started: ", job[1])
        #storeAllUnjoined(job[1], job[2])
    elif(job[0] == "joined"):
        #print(job)
        storeAllJoined(job[1], job[2])
    return job[1]

# pool = Pool(4)

# def mycallback(x):
#     print("Finished: ", x)
#     sys.stdout.flush()

# results = []
# for job in jobs:
#     r = pool.apply_async(doJob, args=[job], callback=mycallback)
#     results.append(r)

# %%
for job in jobs:
    doJob(job)
# Out:
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['Photon.PT', 'Photon.Eta', 'Photon.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Photon.PT, Photon.Eta, Photon.Phi, Photon.PT, Photon.Phi, Photon.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 571/999      Entry        E/c         Px         Py         Pz  ...        Phi  \
# 0         0  37.990608  -9.170443   4.553054 -36.584956  ...   2.680755
# 1         1  13.874844  -4.307627 -13.189224  -0.004160  ...  -1.886477
# 2         2  21.493283  10.851260 -12.083362  14.078485  ...  -0.839069
# 3         2  14.805149   7.657810  -6.624242  10.801380  ...  -0.713156
# 4         3  18.736737 -15.379970  -6.134225   8.768872  ...  -2.762082
# ...     ...        ...        ...        ...        ...  ...        ...
# 1252    992  32.952827   8.295932   6.530593 -31.215663  ...   0.666890
# 1253    993  14.024927 -10.481883   5.444767   7.561959  ...   2.662510
# 1254    998  52.095664  43.042935 -29.327421   1.079973  ...  -0.598101
# 1255    998  12.515358  10.469404  -6.856159  -0.137357  ...  -0.579795
# 1256    998  52.915460 -10.551752   5.283323 -51.582874  ...   2.677381
#
#            Eta  Dxy  Eem  Ehad
# 0    -1.985656    0    0     0
# 1    -0.000300    0    0     0
# 2     0.784037    0    0     0
# 3     0.927806    0    0     0
# 4     0.507512    0    0     0
# ...        ...  ...  ...   ...
# 1252 -1.804629    0    0     0
# 1253  0.602999    0    0     0
# 1254  0.020734    0    0     0
# 1255 -0.010976    0    0     0
# 1256 -2.181025    0    0     0
#
# [1257 rows x 13 columns]
# Elapse time: 1.02 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['Electron.PT', 'Electron.Eta', 'Electron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['Electron.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Electron.PT, Electron.Eta, Electron.Phi, Electron.Charge, Electron.PT, Electron.Phi, Electron.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===============     ] 791/999     Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0        6   51.332318  -7.154917 -16.858434   47.954221  ...  -1.972169
# 1        9  171.148878  15.181958 -14.479567 -169.858143  ...  -0.761722
# 2       14   24.917467  -2.118735  24.682505    2.676766  ...   1.656426
# 3       15   58.290608  19.533425   8.145558   54.312892  ...   0.395080
# 4       16   16.190581 -11.188082   7.387841   -9.076429  ...   2.557989
# ..     ...         ...        ...        ...         ...  ...        ...
# 511    987   55.802952  18.613593 -22.418433   47.591150  ...  -0.877862
# 512    990   44.854141   6.728299   8.012852   43.616719  ...   0.872319
# 513    991   10.498238   6.173455   3.572913   -7.702970  ...   0.524651
# 514    995   18.063153   3.032740  16.601045    6.440908  ...   1.390105
# 515    997   11.785697 -11.203744   1.273440    3.428865  ...   3.028416
#
#           Eta  Dxy  Eem  Ehad
# 0    1.690349    0    0     0
# 1   -2.788346    0    0     0
# 2    0.107841    0    0     0
# 3    1.671582    0    0     0
# 4   -0.633707    0    0     0
# ..        ...  ...  ...   ...
# 511  1.266488    0    0     0
# 512  2.134821    0    0     0
# 513 -0.936780    0    0     0
# 514  0.372959    0    0     0
# 515  0.299587    0    0     0
#
# [516 rows x 13 columns]
# Elapse time: 0.83 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['MuonTight.PT', 'MuonTight.Eta', 'MuonTight.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['MuonTight.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MuonTight.PT, MuonTight.Eta, MuonTight.Phi, MuonTight.Charge, MuonTight.PT, MuonTight.Phi, MuonTight.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 571/999     Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0        1   34.442091 -18.798974  20.557733  -20.254003  ...   2.311537
# 1        2   10.514176  -0.363667  10.355061   -1.782469  ...   1.605902
# 2        3    9.889518   3.635439   7.741704   -4.963971  ...   1.131770
# 3        4  132.934161 -16.724327  -2.472113 -131.854714  ...  -2.994840
# 4        6   34.591623   4.636513   4.752730   33.948248  ...   0.797775
# ..     ...         ...        ...        ...         ...  ...        ...
# 424    991   34.570909  17.814596   7.097136  -28.764690  ...   0.379117
# 425    993   11.776810   0.919903  -5.614926  -10.310600  ...  -1.408407
# 426    994   12.162231   3.437502  11.632666    0.879408  ...   1.283469
# 427    996  132.202681 -56.563442  15.715033 -118.453166  ...   2.870597
# 428    998   86.278603 -15.321650  19.312488  -82.681685  ...   2.241472
#
#           Eta  Dxy  Eem  Ehad
# 0   -0.674699    0    0     0
# 1   -0.171192    0    0     0
# 2   -0.551938    0    0     0
# 3   -2.751261    0    0     0
# 4    2.334346    0    0     0
# ..        ...  ...  ...   ...
# 424 -1.194772    0    0     0
# 425 -1.356314    0    0     0
# 426  0.072436    0    0     0
# 427 -1.451540    0    0     0
# 428 -1.924802    0    0     0
#
# [429 rows x 13 columns]
# Elapse time: 0.73 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowNeutralHadron.ET', 'EFlowNeutralHadron.Eta', 'EFlowNeutralHadron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowNeutralHadron.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowNeutralHadron.ET, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Phi, EFlowNeutralHadron.ET, EFlowNeutralHadron.Phi, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Eem, EFlowNeutralHadron.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 995/999        Entry         E/c        Px        Py          Pz     ...      \
# 0           0   95.165154 -1.324689 -0.444220  -95.154896     ...
# 1           0   31.279904 -0.247088 -0.378927  -31.276633     ...
# 2           0  130.351527 -0.132857 -1.989350 -130.336278     ...
# 3           0  135.830419  0.156916 -2.290424 -135.811016     ...
# 4           0  218.294601  1.349392 -3.563417 -218.261343     ...
# ...       ...         ...       ...       ...         ...     ...
# 412615    998  184.438616 -1.120740  2.428273  184.419225     ...
# 412616    998   46.996478 -0.420166  0.490411   46.992041     ...
# 412617    998    8.421981 -0.108668  0.078287    8.420916     ...
# 412618    998   16.763100 -0.272775  0.084676   16.760667     ...
# 412619    998  156.292355 -2.486242  0.054701  156.272569     ...
#
#              Phi       Eta  Dxy  Eem        Ehad
# 0      -2.818038 -4.914246    0    0   95.165176
# 1      -2.148626 -4.929327    0    0   31.279902
# 2      -1.637481 -4.873291    0    0  130.351517
# 3      -1.502393 -4.773405    0    0  135.830429
# 4      -1.208804 -4.741194    0    0  218.294617
# ...          ...       ...  ...  ...         ...
# 412615  2.003204  4.926676    0    0  184.438660
# 412616  2.279204  4.980456    0    0   46.996471
# 412617  2.517292  4.834358    0    0    8.421979
# 412618  2.840602  4.765362    0    0   16.763100
# 412619  3.119595  4.833798    0    0  156.292328
#
# [412620 rows x 13 columns]
# Elapse time: 9.52 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowPhoton.ET', 'EFlowPhoton.Eta', 'EFlowPhoton.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowPhoton.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowPhoton.ET, EFlowPhoton.Eta, EFlowPhoton.Phi, EFlowPhoton.ET, EFlowPhoton.Phi, EFlowPhoton.Eta, EFlowPhoton.Eem, EFlowPhoton.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 998/999        Entry        E/c        Px        Py         Pz  ...        Phi  \
# 0           0  75.238951 -1.038700 -0.012260 -75.231780  ...  -3.129790
# 1           0  21.711529 -0.265287 -0.123723 -21.709556  ...  -2.705205
# 2           0  30.541305 -0.286751 -0.302411 -30.538462  ...  -2.329620
# 3           0  19.095752 -0.052267 -0.276718 -19.093676  ...  -1.757480
# 4           0  33.524513  0.027310 -0.527499 -33.520352  ...  -1.519070
# ...       ...        ...       ...       ...        ...  ...        ...
# 530494    998  56.368078  0.091685  0.858170  56.361471  ...   1.464363
# 530495    998  18.496095 -0.092388  0.278904  18.493761  ...   1.890674
# 530496    998   4.062451 -0.024639  0.051071   4.062055  ...   2.020299
# 530497    998   7.937839 -0.084999  0.112974   7.936580  ...   2.215814
# 530498    998   9.184959 -0.113238  0.075541   9.183950  ...   2.553291
#
#              Eta  Dxy        Eem  Ehad
# 0      -4.975729    0  75.238968     0
# 1      -4.999486    0  21.711527     0
# 2      -4.987455    0  30.541311     0
# 3      -4.909787    0  19.095749     0
# 4      -4.843632    0  33.524513     0
# ...          ...  ...        ...   ...
# 530494  4.872270    0  56.368069     0
# 530495  4.835473    0  18.496094     0
# 530496  4.964807    0   4.062450     0
# 530497  4.721022    0   7.937838     0
# 530498  4.904864    0   9.184960     0
#
# [530499 rows x 13 columns]
# Elapse time: 11.96 seconds
# ([<CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0beeffdfc8>, <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0c1cbfa5a8>, 'EFlowTrack.Charge', 'EFlowTrack.PT', 'EFlowTrack.Phi', 'EFlowTrack.Eta', 'EFlowTrack.Dxy', <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0beeee1290>], ['E/c', 'Px', 'Py', 'Pz', 'PID', 'Charge', 'PT', 'Phi', 'Eta', 'Dxy', 'Eem', 'Ehad'])
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowTrack.PT', 'EFlowTrack.Eta', 'EFlowTrack.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: EFlowTrack.PT, EFlowTrack.Eta, EFlowTrack.Phi, EFlowTrack.Charge, EFlowTrack.PT, EFlowTrack.Phi, EFlowTrack.Eta, EFlowTrack.Dxy
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 993/999        Entry        E/c        Px        Py         Pz  ...        Phi  \
# 0           0  21.663058 -0.867984 -0.294290 -21.643662  ...  -2.814706
# 1           0  59.814815 -0.261359 -2.282516 -59.770677  ...  -1.684805
# 2           0  46.021790  0.457006 -1.724246 -45.987208  ...  -1.311707
# 3           0  25.016007  0.501694 -0.860216 -24.996179  ...  -1.042808
# 4           0  24.981050  0.831939 -0.436450 -24.963378  ...  -0.483147
# ...       ...        ...       ...       ...        ...  ...        ...
# 413880    998  28.397390  0.673357  1.053906  28.369836  ...   1.002253
# 413881    998   0.393981 -0.016180 -0.258217   0.297124  ...  -1.633373
# 413882    998  19.243507 -0.275506  0.803407  19.224754  ...   1.901152
# 413883    998  12.252966 -0.276707  0.410010  12.242977  ...   2.164462
# 413884    998   7.392444 -0.283094  0.122020   7.386013  ...   2.734631
#
#              Eta           Dxy  Eem  Ehad
# 0      -3.855482 -0.000000e+00    0     0
# 1      -3.952240  5.999571e-14    0     0
# 2      -3.943150 -5.804058e-14    0     0
# 3      -3.916450  9.290027e-14    0     0
# 4      -3.973346  0.000000e+00    0     0
# ...          ...           ...  ...   ...
# 413880  3.815295 -4.572568e-14    0     0
# 413881  0.982530  9.960494e-15    0     0
# 413882  3.813138 -1.224348e-14    0     0
# 413883  3.902420 -6.174159e-14    0     0
# 413884  3.869946 -6.573776e-15    0     0
#
# [413885 rows x 13 columns]
# Elapse time: 8.82 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1.root
# Using trees: Delphes
# Procedure at column 1 maps "['MissingET.MET', 'MissingET.Eta', 'MissingET.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['MissingET.MET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MissingET.MET, MissingET.Eta, MissingET.Phi, MissingET.MET, MissingET.Phi, MissingET.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 571/999     Entry          E/c         Px         Py           Pz  ...        Phi  \
# 0        0  4251.800875 -39.166558 -13.996764  4251.597435  ...  -2.798372
# 1        1   172.667067 -16.326244  34.141620  -168.468750  ...   2.016846
# 2        2  3004.437975  14.927612  -2.918029  3004.399474  ...  -0.193044
# 3        3  1171.844071  17.422830  23.037570  1171.488046  ...   0.923289
# 4        4   676.041237 -30.714733  10.960861  -675.254189  ...   2.798820
# ..     ...          ...        ...        ...          ...  ...        ...
# 994    994   485.049061 -19.572011  -7.422398  -484.597189  ...  -2.779114
# 995    995  1416.954529   9.365557   3.549553 -1416.919131  ...   0.362274
# 996    996  2577.728086 -39.598861   4.416491  2577.420127  ...   3.030521
# 997    997  1838.077158 -30.616040 -20.192620 -1837.711227  ...  -2.558537
# 998    998   284.202532 -32.640663 -40.222329  -279.441998  ...  -2.252514
#
#           Eta  Dxy  Eem  Ehad
# 0    5.320303    0    0     0
# 1   -2.198798    0    0     0
# 2    5.979024    0    0     0
# 3    4.396042    0    0     0
# 4   -3.724142    0    0     0
# ..        ...  ...  ...   ...
# 994 -3.835644    0    0     0
# 995 -5.645252    0    0     0
# 996  4.862770    0    0     0
# 997 -4.607417    0    0     0
# 998 -2.387032    0    0     0
#
# [999 rows x 13 columns]
# Elapse time: 0.76 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['Photon.PT', 'Photon.Eta', 'Photon.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Photon.PT, Photon.Eta, Photon.Phi, Photon.PT, Photon.Phi, Photon.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 572/999      Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0         0   75.887713 -21.316214 -10.008543   72.141480  ...  -2.702619
# 1         0   25.536751  10.676807   7.033009   22.105842  ...   0.582480
# 2         2   23.299692  21.717079   6.433890    5.463443  ...   0.288022
# 3         2   20.693985  19.396818   5.599346    4.544425  ...   0.281033
# 4         4   15.405600 -10.145792   3.185410   11.146685  ...   2.837375
# ...     ...         ...        ...        ...         ...  ...        ...
# 1293    997  165.723837  11.495049  -9.044822  165.077089  ...  -0.666668
# 1294    998   23.301502  -1.379831 -23.255904   -0.467953  ...  -1.630059
# 1295    998   21.948516  -0.977995 -21.921484   -0.478991  ...  -1.615380
# 1296    998   21.497779 -11.512327   3.219948   17.867646  ...   2.868866
# 1297    998   46.871434   4.337398  10.052515   45.574831  ...   1.163455
#
#            Eta  Dxy  Eem  Ehad
# 0     1.838329    0    0     0
# 1     1.315451    0    0     0
# 2     0.238931    0    0     0
# 3     0.223237    0    0     0
# 4     0.915051    0    0     0
# ...        ...  ...  ...   ...
# 1293  3.118657    0    0     0
# 1294 -0.020085    0    0     0
# 1295 -0.021827    0    0     0
# 1296  1.191809    0    0     0
# 1297  2.133440    0    0     0
#
# [1298 rows x 13 columns]
# Elapse time: 1.03 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['Electron.PT', 'Electron.Eta', 'Electron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['Electron.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Electron.PT, Electron.Eta, Electron.Phi, Electron.Charge, Electron.PT, Electron.Phi, Electron.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===============     ] 786/999     Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0        0   46.785589 -13.228026  -6.176953   44.449476  ...  -2.704725
# 1        8   30.852854  14.739149 -23.096567   14.184663  ...  -1.002794
# 2       12   54.889477   3.369881  11.145438  -53.640263  ...   1.277180
# 3       13   37.229078  31.620542 -16.071653   11.306969  ...  -0.470239
# 4       14  128.051542   6.410466  -7.483230 -127.671863  ...  -0.862458
# ..     ...         ...        ...        ...         ...  ...        ...
# 507    993   28.447917   9.790747 -12.509247   23.599661  ...  -0.906705
# 508    994   27.607706   6.475993  -8.432122   25.478349  ...  -0.915865
# 509    994   23.456754   5.426582  -7.205426   21.653022  ...  -0.925299
# 510    996   32.629866   8.374606   7.136618   30.718770  ...   0.705755
# 511    998    6.033645   0.666763  -5.995000    0.142411  ...  -1.460032
#
#           Eta  Dxy  Eem  Ehad
# 0    1.832475    0    0     0
# 1    0.496997    0    0     0
# 2   -2.232255    0    0     0
# 3    0.313605    0    0     0
# 4   -3.256263    0    0     0
# ..        ...  ...  ...   ...
# 507  1.186770    0    0     0
# 508  1.608047    0    0     0
# 509  1.609621    0    0     0
# 510  1.750488    0    0     0
# 511  0.023607    0    0     0
#
# [512 rows x 13 columns]
# Elapse time: 0.83 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['MuonTight.PT', 'MuonTight.Eta', 'MuonTight.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['MuonTight.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MuonTight.PT, MuonTight.Eta, MuonTight.Phi, MuonTight.Charge, MuonTight.PT, MuonTight.Phi, MuonTight.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 572/999     Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0        1  106.215910  32.768939  -1.639609 -101.021367  ...  -0.049994
# 1        4   15.704518 -10.563023   3.341109   11.130150  ...   2.835248
# 2        4   17.740169   9.403276  -2.928843  -14.754753  ...  -0.301947
# 3        6   27.143759 -12.708539   7.262637   22.858688  ...   2.622410
# 4        7   49.384280  -7.610533  18.185149  -45.278870  ...   1.967151
# ..     ...         ...        ...        ...         ...  ...        ...
# 445    990   14.988915  -2.613794  12.593654   -7.695737  ...   1.775439
# 446    991  205.206388  -2.629063  27.447775  203.345416  ...   1.666289
# 447    991    9.148969   1.806289  -8.200485    3.630680  ...  -1.353992
# 448    995   12.027155  -3.044542  10.368387    5.279073  ...   1.856405
# 449    998   22.073528  -3.034077 -21.836795   -1.085457  ...  -1.708856
#
#           Eta  Dxy  Eem  Ehad
# 0   -1.843133    0    0     0
# 1    0.884645    0    0     0
# 2   -1.193720    0    0     0
# 3    1.228489    0    0     0
# 4   -1.569023    0    0     0
# ..        ...  ...  ...   ...
# 445 -0.567392    0    0     0
# 446  2.695767    0    0     0
# 447  0.419924    0    0     0
# 448  0.470925    0    0     0
# 449 -0.049215    0    0     0
#
# [450 rows x 13 columns]
# Elapse time: 0.72 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowNeutralHadron.ET', 'EFlowNeutralHadron.Eta', 'EFlowNeutralHadron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowNeutralHadron.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowNeutralHadron.ET, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Phi, EFlowNeutralHadron.ET, EFlowNeutralHadron.Phi, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Eem, EFlowNeutralHadron.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 980/999        Entry         E/c        Px        Py          Pz     ...      \
# 0           0   97.454116 -0.762383 -1.252001  -97.443091     ...
# 1           0  443.987464 -2.994839 -6.852689 -443.924475     ...
# 2           0   71.790294 -0.244804 -1.169033  -71.780358     ...
# 3           0   53.496377 -0.052806 -0.740681  -53.491223     ...
# 4           0   20.370820  0.002911 -0.315138  -20.368382     ...
# ...       ...         ...       ...       ...         ...     ...
# 410146    998   29.818303 -0.028812  0.539968   29.813400     ...
# 410147    998   28.633343 -0.166098  0.470468   28.628996     ...
# 410148    998  144.530902 -0.796717  1.879402  144.516486     ...
# 410149    998   35.403059 -0.308498  0.463132   35.398685     ...
# 410150    998   22.820861 -0.355624  0.119840   22.817775     ...
#
#              Phi       Eta  Dxy  Eem        Ehad
# 0      -2.117758 -4.890033    0    0   97.454132
# 1      -1.982813 -4.776836    0    0  443.987549
# 2      -1.777220 -4.789192    0    0   71.790283
# 3      -1.641970 -4.970363    0    0   53.496376
# 4      -1.561560 -4.861892    0    0   20.370825
# ...          ...       ...  ...  ...         ...
# 410146  1.624104  4.703011    0    0   29.818308
# 410147  1.910185  4.742937    0    0   28.633347
# 410148  1.971752  4.953003    0    0  144.530930
# 410149  2.158415  4.846019    0    0   35.403053
# 410150  2.816559  4.800857    0    0   22.820858
#
# [410151 rows x 13 columns]
# Elapse time: 9.80 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowPhoton.ET', 'EFlowPhoton.Eta', 'EFlowPhoton.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowPhoton.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowPhoton.ET, EFlowPhoton.Eta, EFlowPhoton.Phi, EFlowPhoton.ET, EFlowPhoton.Phi, EFlowPhoton.Eta, EFlowPhoton.Eem, EFlowPhoton.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 978/999        Entry         E/c        Px        Py          Pz  ...        Phi  \
# 0           0   34.922986 -0.532806 -0.127355  -34.918689  ...  -2.906968
# 1           0  210.285662 -1.517404 -3.227448 -210.255418  ...  -2.010285
# 2           0   48.261679 -0.091626 -0.711707  -48.256344  ...  -1.698834
# 3           0   20.275643  0.185590 -0.233879  -20.273444  ...  -0.900012
# 4           0   85.732359  1.383798  0.690784  -85.718407  ...   0.463003
# ...       ...         ...       ...       ...         ...  ...        ...
# 527809    998   51.794563  0.645009  0.621035   51.786823  ...   0.766465
# 527810    998   40.685534 -0.089404  0.579646   40.681307  ...   1.723829
# 527811    998    6.369747 -0.035740  0.108117    6.368729  ...   1.890059
# 527812    998    6.790355 -0.094571  0.049653    6.789515  ...   2.658119
# 527813    998   14.853019 -0.200234  0.062053   14.851540  ...   2.841076
#
#              Eta  Dxy         Eem  Ehad
# 0      -4.848048    0   34.922989     0
# 1      -4.769996    0  210.285629     0
# 2      -4.901599    0   48.261688     0
# 3      -4.911271    0   20.275640     0
# 4      -4.708215    0   85.732346     0
# ...          ...  ...         ...   ...
# 527809  4.750855    0   51.794567     0
# 527810  4.932550    0   40.685532     0
# 527811  4.717316    0    6.369747     0
# 527812  4.845262    0    6.790353     0
# 527813  4.953718    0   14.853020     0
#
# [527814 rows x 13 columns]
# Elapse time: 11.93 seconds
# ([<CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0beeeaf518>, <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0be6794758>, 'EFlowTrack.Charge', 'EFlowTrack.PT', 'EFlowTrack.Phi', 'EFlowTrack.Eta', 'EFlowTrack.Dxy', <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0beeee1290>], ['E/c', 'Px', 'Py', 'Pz', 'PID', 'Charge', 'PT', 'Phi', 'Eta', 'Dxy', 'Eem', 'Ehad'])
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowTrack.PT', 'EFlowTrack.Eta', 'EFlowTrack.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: EFlowTrack.PT, EFlowTrack.Eta, EFlowTrack.Phi, EFlowTrack.Charge, EFlowTrack.PT, EFlowTrack.Phi, EFlowTrack.Eta, EFlowTrack.Dxy
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 990/999        Entry        E/c        Px        Py         Pz  ...        Phi  \
# 0           0   4.926988 -0.195069  0.009018  -4.923116  ...   3.095397
# 1           0  13.474762  0.166228 -0.477317 -13.465279  ...  -1.235676
# 2           0  85.064760  1.565476 -3.020941 -84.996686  ...  -1.092689
# 3           0  20.237729  0.769111 -0.073550 -20.222976  ...  -0.095340
# 4           0  30.263436  0.353571  1.149323 -30.239537  ...   1.272351
# ...       ...        ...       ...       ...        ...  ...        ...
# 411600    998   5.161469 -0.027936 -0.201579   5.157456  ...  -1.708504
# 411601    998   6.620676  0.214785 -0.169038   6.615032  ...  -0.666769
# 411602    998  22.956718  0.853127 -0.228846  22.939719  ...  -0.262074
# 411603    998   0.607938  0.249285  0.217906   0.509866  ...   0.718332
# 411604    998  72.937078 -2.077081  1.957996  72.881200  ...   2.385698
#
#              Eta           Dxy  Eem  Ehad
# 0      -3.920818 -3.740283e-14    0     0
# 1      -3.975952  1.545571e-14    0     0
# 2      -3.911658 -1.606689e-13    0     0
# 3      -3.958300  7.933258e-16    0     0
# 4      -3.918308  6.604019e-14    0     0
# ...          ...           ...  ...   ...
# 411600  3.926043 -1.548518e-14    0     0
# 411601  3.880012 -0.000000e+00    0     0
# 411602  3.950493  6.540246e-15    0     0
# 411603  1.216707  0.000000e+00    0     0
# 411604  3.933474 -1.122158e-13    0     0
#
# [411605 rows x 13 columns]
# Elapse time: 9.18 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_10.root
# Using trees: Delphes
# Procedure at column 1 maps "['MissingET.MET', 'MissingET.Eta', 'MissingET.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['MissingET.MET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MissingET.MET, MissingET.Eta, MissingET.Phi, MissingET.MET, MissingET.Phi, MissingET.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 572/999     Entry          E/c         Px         Py           Pz  ...        Phi  \
# 0        0   627.314214  22.783863  -1.193096  -626.899190  ...  -0.052318
# 1        1   744.394255  22.958468  14.014060   743.908141  ...   0.548038
# 2        2   162.513649 -11.755807 -16.465858  -161.249380  ...  -2.190824
# 3        3   257.502531  28.290101   7.858036   255.823132  ...   0.270936
# 4        4  1546.089315  55.420526   2.571575 -1545.093564  ...   0.046368
# ..     ...          ...        ...        ...          ...  ...        ...
# 994    994  1198.560830  -5.834939  27.715406  1198.226136  ...   1.778297
# 995    995  1841.466333 -31.875054   4.598590 -1841.184697  ...   2.998312
# 996    996  3842.752267  12.805039   4.935873 -3842.727762  ...   0.367912
# 997    997  2693.478116  21.023142 -33.099337 -2693.192682  ...  -1.004929
# 998    998  3740.971770 -24.496125 -62.896424 -3740.362785  ...  -1.942190
#
#           Eta  Dxy  Eem  Ehad
# 0   -4.006842    0    0     0
# 1    4.013351    0    0     0
# 2   -2.772759    0    0     0
# 3    2.861237    0    0     0
# 4   -4.020284    0    0     0
# ..        ...  ...  ...   ...
# 994  4.438211    0    0     0
# 995 -4.739264    0    0     0
# 996 -6.327985    0    0     0
# 997 -4.922714    0    0     0
# 998 -4.708064    0    0     0
#
# [999 rows x 13 columns]
# Elapse time: 0.74 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['Photon.PT', 'Photon.Eta', 'Photon.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Photon.PT, Photon.Eta, Photon.Phi, Photon.PT, Photon.Phi, Photon.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 577/999      Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0         1   42.343292  14.142405  -4.129584  -39.697522  ...  -0.284101
# 1         3   26.602821   7.001534  16.131676  -19.961404  ...   1.161307
# 2         4   20.385399   8.720719   5.916156   17.450291  ...   0.596083
# 3         5   46.293573   7.583754 -25.168344  -38.106902  ...  -1.278128
# 4         5   17.779810   2.692449  -9.831998  -14.567229  ...  -1.303504
# ...     ...         ...        ...        ...         ...  ...        ...
# 1353    993   14.537498  -6.695793  10.018879   -8.131868  ...   2.159941
# 1354    994   27.662800 -12.758053 -24.094456    4.681859  ...  -2.057766
# 1355    997  545.011024 -29.527269   2.185427 -544.206193  ...   3.067713
# 1356    997  209.966085 -10.178832   0.110154 -209.719184  ...   3.130771
# 1357    998   17.321977 -15.234442   8.243158   -0.114026  ...   2.645618
#
#            Eta  Dxy  Eem  Ehad
# 0    -1.717127    0    0     0
# 1    -0.973754    0    0     0
# 2     1.278254    0    0     0
# 3    -1.166533    0    0     0
# 4    -1.154724    0    0     0
# ...        ...  ...  ...   ...
# 1353 -0.631919    0    0     0
# 1354  0.170892    0    0     0
# 1355 -3.605169    0    0     0
# 1356 -3.719136    0    0     0
# 1357 -0.006583    0    0     0
#
# [1358 rows x 13 columns]
# Elapse time: 0.75 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['Electron.PT', 'Electron.Eta', 'Electron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['Electron.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Electron.PT, Electron.Eta, Electron.Phi, Electron.Charge, Electron.PT, Electron.Phi, Electron.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 577/999     Entry        E/c         Px         Py         Pz  ...        Phi  \
# 0        0  52.291643 -24.880955   9.279371  45.047167  ...   2.784620
# 1        2  24.556108  17.514449  14.753323  -8.864874  ...   0.700037
# 2        3  36.723926  -4.974569 -19.155680 -30.934775  ...  -1.824875
# 3        4  10.093206  -5.114487  -8.686321   0.512508  ...  -2.102938
# 4        6  34.043277  10.908186   1.539577 -32.211580  ...   0.140213
# ..     ...        ...        ...        ...        ...  ...        ...
# 499    993  40.215938 -18.844132  28.159462 -21.662527  ...   2.160546
# 500    993  16.819531  -7.881014  11.777392  -9.059763  ...   2.160526
# 501    994  28.144547 -12.837766 -24.650796   4.432326  ...  -2.050933
# 502    995  22.652137 -13.768113  -4.436678 -17.431990  ...  -2.829856
# 503    997  23.860480  12.487323   1.635393 -20.266099  ...   0.130223
#
#           Eta  Dxy  Eem  Ehad
# 0    1.298979    0    0     0
# 1   -0.378041    0    0     0
# 2   -1.229245    0    0     0
# 3    0.050821    0    0     0
# 4   -1.794133    0    0     0
# ..        ...  ...  ...   ...
# 499 -0.602259    0    0     0
# 500 -0.602245    0    0     0
# 501  0.158806    0    0     0
# 502 -1.019227    0    0     0
# 503 -1.253845    0    0     0
#
# [504 rows x 13 columns]
# Elapse time: 0.72 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['MuonTight.PT', 'MuonTight.Eta', 'MuonTight.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['MuonTight.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MuonTight.PT, MuonTight.Eta, MuonTight.Phi, MuonTight.Charge, MuonTight.PT, MuonTight.Phi, MuonTight.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 577/999     Entry        E/c         Px         Py         Pz  ...        Phi  \
# 0        2   8.628242   5.481760   5.921730  -3.052673  ...   0.823961
# 1        5  15.395284  -6.502257  13.197544  -4.533109  ...   2.028576
# 2        6  43.392110  13.536270   2.990972 -41.117971  ...   0.217466
# 3        9  66.596744  22.660865  26.325425  56.820527  ...   0.860067
# 4       14  11.397481   6.512936   8.649439  -3.558127  ...   0.925385
# ..     ...        ...        ...        ...        ...  ...        ...
# 423    988  28.491756  -6.944018 -15.632498 -22.785403  ...  -1.988820
# 424    990  23.801885  -7.766159  10.349956  19.977081  ...   2.214526
# 425    991  39.159108   5.906419 -38.210541   6.204301  ...  -1.417434
# 426    991   8.465876   0.839999  -8.329645   1.253516  ...  -1.470292
# 427    998  76.753941   8.438124   7.863521  75.882273  ...   0.750165
#
#           Eta  Dxy  Eem  Ehad
# 0   -0.369811    0    0     0
# 1   -0.303437    0    0     0
# 2   -1.807662    0    0     0
# 3    1.267813    0    0     0
# 4   -0.322980    0    0     0
# ..        ...  ...  ...   ...
# 423 -1.097848    0    0     0
# 424  1.218851    0    0     0
# 425  0.159785    0    0     0
# 426  0.149175    0    0     0
# 427  2.582744    0    0     0
#
# [428 rows x 13 columns]
# Elapse time: 0.74 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowNeutralHadron.ET', 'EFlowNeutralHadron.Eta', 'EFlowNeutralHadron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowNeutralHadron.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowNeutralHadron.ET, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Phi, EFlowNeutralHadron.ET, EFlowNeutralHadron.Phi, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Eem, EFlowNeutralHadron.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 975/999        Entry        E/c        Px        Py         Pz    ...           Phi  \
# 0           0  18.661822 -0.284327 -0.170519 -18.658877    ...     -2.601371
# 1           0  32.364948 -0.317471 -0.330856 -32.361699    ...     -2.335551
# 2           0  10.169940 -0.088970 -0.115331 -10.168897    ...     -2.227873
# 3           0  34.087630 -0.120849 -0.555793 -34.082885    ...     -1.784899
# 4           0  15.942867  0.068035 -0.226779 -15.941109    ...     -1.279335
# ...       ...        ...       ...       ...        ...    ...           ...
# 408512    998  68.020474  0.636549  0.712085  68.013768    ...      0.841349
# 408513    998  22.616959 -0.070765  0.372755  22.613776    ...      1.758406
# 408514    998  13.670167 -0.104428  0.199140  13.668318    ...      2.053768
# 408515    998  29.553395 -0.329232  0.278257  29.550251    ...      2.439909
# 408516    998  38.017803 -0.517073  0.414412  38.012028    ...      2.465964
#
#              Eta  Dxy  Eem       Ehad
# 0      -4.723556    0    0  18.661823
# 1      -4.949893    0    0  32.364952
# 2      -4.939008    0    0  10.169941
# 3      -4.786273    0    0  34.087631
# 4      -4.902792    0    0  15.942865
# ...          ...  ...  ...        ...
# 408512  4.958822    0    0  68.020485
# 408513  4.780908    0    0  22.616955
# 408514  4.800575    0    0  13.670166
# 408515  4.920780    0    0  29.553392
# 408516  4.742638    0    0  38.017803
#
# [408517 rows x 13 columns]
# Elapse time: 9.33 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowPhoton.ET', 'EFlowPhoton.Eta', 'EFlowPhoton.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowPhoton.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowPhoton.ET, EFlowPhoton.Eta, EFlowPhoton.Phi, EFlowPhoton.ET, EFlowPhoton.Phi, EFlowPhoton.Eta, EFlowPhoton.Eem, EFlowPhoton.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 982/999        Entry        E/c        Px        Py         Pz  ...        Phi  \
# 0           0  23.823286 -0.380448 -0.099939 -23.820039  ...  -2.884708
# 1           0  56.670634 -0.647283 -0.488352 -56.664833  ...  -2.495240
# 2           0  10.210936  0.051232 -0.129358 -10.209988  ...  -1.193698
# 3           0   6.556313  0.066724 -0.095238  -6.555281  ...  -0.959665
# 4           0  30.153524  0.402983 -0.239938 -30.149877  ...  -0.537034
# ...       ...        ...       ...       ...        ...  ...        ...
# 527306    998  13.402856  0.102240  0.162251  13.401484  ...   1.008514
# 527307    998   4.358047 -0.008225  0.064070   4.357568  ...   1.698473
# 527308    998  61.868193 -0.375503  0.907935  61.860391  ...   1.962953
# 527309    998  14.117214 -0.157844  0.163957  14.115379  ...   2.337199
# 527310    998   4.523446 -0.061811  0.010624   4.523012  ...   2.971373
#
#              Eta  Dxy        Eem  Ehad
# 0      -4.796783    0  23.823284     0
# 1      -4.940035    0  56.670647     0
# 2      -4.988879    0  10.210936     0
# 3      -4.725199    0   6.556312     0
# 4      -4.856531    0  30.153528     0
# ...          ...  ...        ...   ...
# 527306  4.939985    0  13.402856     0
# 527307  4.904721    0   4.358047     0
# 527308  4.835723    0  61.868183     0
# 527309  4.820693    0  14.117211     0
# 527310  4.971488    0   4.523447     0
#
# [527311 rows x 13 columns]
# Elapse time: 11.85 seconds
# ([<CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0be67653f8>, <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0be6765b90>, 'EFlowTrack.Charge', 'EFlowTrack.PT', 'EFlowTrack.Phi', 'EFlowTrack.Eta', 'EFlowTrack.Dxy', <CMS_Deep_Learning.utils.data_parse.DataProcessingProcedure instance at 0x7f0beeee1290>], ['E/c', 'Px', 'Py', 'Pz', 'PID', 'Charge', 'PT', 'Phi', 'Eta', 'Dxy', 'Eem', 'Ehad'])
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowTrack.PT', 'EFlowTrack.Eta', 'EFlowTrack.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: EFlowTrack.PT, EFlowTrack.Eta, EFlowTrack.Phi, EFlowTrack.Charge, EFlowTrack.PT, EFlowTrack.Phi, EFlowTrack.Eta, EFlowTrack.Dxy
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [=================== ] 969/999        Entry        E/c        Px        Py         Pz  ...        Phi  \
# 0           0  20.637803  0.589550 -0.572164 -20.621445  ...  -0.770434
# 1           0   0.253987 -0.230979 -0.035113  -0.099625  ...  -2.990728
# 2           0   8.457014  0.308912  0.163854  -8.449781  ...   0.487687
# 3           0  11.665195 -0.143978  0.484187 -11.654253  ...   1.859830
# 4           0  22.196903 -0.657549  0.467178 -22.182242  ...   2.523866
# ...       ...        ...       ...       ...        ...  ...        ...
# 410890    998   6.193842  0.213901  0.131201   6.188757  ...   0.550194
# 410891    998  12.809940  0.357566  0.399272  12.798722  ...   0.840449
# 410892    998   6.718547  0.055728  0.301156   6.711563  ...   1.387818
# 410893    998  23.686426 -0.794330  0.454130  23.668747  ...   2.622231
# 410894    998   8.740344 -0.310823  0.163688   8.733282  ...   2.656871
#
#              Eta           Dxy  Eem  Ehad
# 0      -3.916441  3.583863e-14    0     0
# 1      -0.414450 -6.152800e-16    0     0
# 2      -3.878458  0.000000e+00    0     0
# 3      -3.832206 -3.163322e-14    0     0
# 4      -4.007680  0.000000e+00    0     0
# ...          ...           ...  ...   ...
# 410890  3.898862 -3.337765e-07    0     0
# 410891  3.866595  0.000000e+00    0     0
# 410892  3.780792  4.523987e-14    0     0
# 410893  3.946526  0.000000e+00    0     0
# 410894  3.906836  6.956733e-15    0     0
#
# [410895 rows x 13 columns]
# Elapse time: 8.78 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_100.root
# Using trees: Delphes
# Procedure at column 1 maps "['MissingET.MET', 'MissingET.Eta', 'MissingET.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['MissingET.MET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MissingET.MET, MissingET.Eta, MissingET.Phi, MissingET.MET, MissingET.Phi, MissingET.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 577/999     Entry          E/c         Px         Py           Pz  ...        Phi  \
# 0        0   459.446328 -31.968079  -7.421128   458.272732  ...  -2.913491
# 1        1   317.815435  51.204536  -9.257352  -313.526789  ...  -0.178860
# 2        2   488.758230  14.878968  47.280700   486.238377  ...   1.265914
# 3        3   732.484287   3.643222 -30.254897   731.850120  ...  -1.450956
# 4        4  2101.966301  -3.136870 -34.598426 -2101.679195  ...  -1.661214
# ..     ...          ...        ...        ...          ...  ...        ...
# 994    994  1555.390404 -61.509796 -63.721082  1552.866858  ...  -2.338539
# 995    995   489.647793 -38.689784 -19.653610   487.721024  ...  -2.671582
# 996    996  1203.933466  38.829221  -3.778168 -1203.301213  ...  -0.096997
# 997    997  2287.709540   2.692174 -17.197362  2287.643316  ...  -1.415511
# 998    998   818.339827  12.042058  -8.449893  -818.207590  ...  -0.611865
#
#           Eta  Dxy  Eem  Ehad
# 0    3.330909    0    0     0
# 1   -2.495939    0    0     0
# 2    2.979117    0    0     0
# 3    3.872300    0    0     0
# 4   -4.795806    0    0     0
# ..        ...  ...  ...   ...
# 994  3.558076    0    0     0
# 995  3.114510    0    0     0
# 996 -4.122349    0    0     0
# 997  5.571578    0    0     0
# 998 -4.711752    0    0     0
#
# [999 rows x 13 columns]
# Elapse time: 0.75 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1000.root
# Using trees: Delphes
# Procedure at column 1 maps "['Photon.PT', 'Photon.Eta', 'Photon.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Photon.PT, Photon.Eta, Photon.Phi, Photon.PT, Photon.Phi, Photon.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 576/999      Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0         0   45.452464 -28.383907  -2.423257   35.417625  ...  -3.056425
# 1         0   33.899306  12.639952   1.237336   31.430297  ...   0.097580
# 2         0   19.799611 -12.568356  -0.920748   15.271321  ...  -3.068464
# 3         1  269.276538  50.584727 -20.766623 -263.666051  ...  -0.389552
# 4         2  219.667391   5.840231 -11.604297 -219.282910  ...  -1.104527
# ...     ...         ...        ...        ...         ...  ...        ...
# 1298    996   29.897006  -6.504766  17.106562   23.640738  ...   1.934162
# 1299    997   33.251667  12.289591  25.201893  -17.874672  ...   1.117081
# 1300    997   10.340098   5.893228   8.411490    1.197641  ...   0.959657
# 1301    998   65.704430  18.787508  -4.011584   62.833183  ...  -0.210365
# 1302    998   15.716530  -9.385205   5.785452  -11.200706  ...   2.589170
#
#            Eta  Dxy  Eem  Ehad
# 0     1.043391    0    0     0
# 1     1.637814    0    0     0
# 2     1.023514    0    0     0
# 3    -2.276888    0    0     0
# 4    -3.520124    0    0     0
# ...        ...  ...  ...   ...
# 1298  1.073402    0    0     0
# 1299 -0.600714    0    0     0
# 1300  0.116347    0    0     0
# 1301  1.900738    0    0     0
# 1302 -0.892590    0    0     0
#
# [1303 rows x 13 columns]
# Elapse time: 1.12 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1000.root
# Using trees: Delphes
# Procedure at column 1 maps "['Electron.PT', 'Electron.Eta', 'Electron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['Electron.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: Electron.PT, Electron.Eta, Electron.Phi, Electron.Charge, Electron.PT, Electron.Phi, Electron.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===============     ] 780/999     Entry         E/c         Px         Py          Pz  ...        Phi  \
# 0        2  402.945226  10.613613 -19.392103 -402.338356  ...  -1.070016
# 1        4   86.794648  -9.734717  21.605702  -83.496945  ...   1.994118
# 2        9   25.766965 -16.361230   3.969785  -19.506087  ...   2.903559
# 3       10   90.191679  49.027942  63.608673  -41.045543  ...   0.914132
# 4       13   14.582991  -1.332785 -11.181005   -9.266739  ...  -1.689437
# ..     ...         ...        ...        ...         ...  ...        ...
# 513    986   18.488967 -15.715830   1.555425    9.614325  ...   3.042942
# 514    989   16.840895   6.747789 -13.408381   -7.635340  ...  -1.104551
# 515    990   23.292463   8.640575  11.619312  -18.244750  ...   0.931379
# 516    993   19.182301 -10.931310   1.719340  -15.668791  ...   2.985585
# 517    997   40.800918  15.014664  31.393681  -21.300508  ...   1.124683
#
#           Eta  Dxy  Eem  Ehad
# 0   -3.595318    0    0     0
# 1   -1.972143    0    0     0
# 2   -0.989196    0    0     0
# 3   -0.491104    0    0     0
# 4   -0.750502    0    0     0
# ..        ...  ...  ...   ...
# 513  0.576344    0    0     0
# 514 -0.488948    0    0     0
# 515 -1.053827    0    0     0
# 516 -1.147234    0    0     0
# 517 -0.579167    0    0     0
#
# [518 rows x 13 columns]
# Elapse time: 0.85 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1000.root
# Using trees: Delphes
# Procedure at column 1 maps "['MuonTight.PT', 'MuonTight.Eta', 'MuonTight.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "['MuonTight.Charge'] -> ['PID', 'Charge']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Procedure at column 11 maps "[] -> ['Eem', 'Ehad']"
# Extracting Leaves: MuonTight.PT, MuonTight.Eta, MuonTight.Phi, MuonTight.Charge, MuonTight.PT, MuonTight.Phi, MuonTight.Eta
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [===========         ] 576/999     Entry        E/c         Px         Py         Pz  ...        Phi  \
# 0        0  46.146059  17.154573  -0.164809  42.838546  ...  -0.009607
# 1        4  49.765585  -8.416510   9.222961 -48.173661  ...   2.310508
# 2        5  67.028570  66.529601  -6.001235   5.533113  ...  -0.089961
# 3        6  11.392515  -8.651744  -6.474887   3.605746  ...  -2.499122
# 4        7  13.572122  10.842542   7.751672   2.557770  ...   0.620677
# ..     ...        ...        ...        ...        ...  ...        ...
# 437    985  17.509913  -4.878571  12.781466  10.927925  ...   1.935420
# 438    988  21.212421  -9.258323  -4.535065  18.538400  ...  -2.686109
# 439    992  35.174416  17.420836  -5.905002 -29.981225  ...  -0.326808
# 440    994  24.588803   8.056944   7.103214  22.118501  ...   0.722571
# 441    998  64.188538  18.130227  -4.228850  61.429381  ...  -0.229152
#
#           Eta  Dxy  Eem  Ehad
# 0    1.646151    0    0     0
# 1   -2.059737    0    0     0
# 2    0.082737    0    0     0
# 3    0.327769    0    0     0
# 4    0.190743    0    0     0
# ..        ...  ...  ...   ...
# 437  0.731710    0    0     0
# 438  1.349570    0    0     0
# 439 -1.264729    0    0     0
# 440  1.469823    0    0     0
# 441  1.909175    0    0     0
#
# [442 rows x 13 columns]
# Elapse time: 0.73 seconds
# Extracting data from /data/shared/Delphes/qcd_lepFilter_13TeV/qcd_lepFilter_13TeV_1000.root
# Using trees: Delphes
# Procedure at column 1 maps "['EFlowNeutralHadron.ET', 'EFlowNeutralHadron.Eta', 'EFlowNeutralHadron.Phi'] -> ['E/c', 'Px', 'Py', 'Pz']"
# Procedure at column 5 maps "[] -> ['PID']"
# Procedure at column 6 maps "[] -> ['Charge']"
# Procedure at column 7 maps "['EFlowNeutralHadron.ET'] -> ['PT']"
# Procedure at column 10 maps "[] -> ['Dxy']"
# Extracting Leaves: EFlowNeutralHadron.ET, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Phi, EFlowNeutralHadron.ET, EFlowNeutralHadron.Phi, EFlowNeutralHadron.Eta, EFlowNeutralHadron.Eem, EFlowNeutralHadron.Ehad
# Renaming to: E/c, Px, Py, Pz, PID, Charge, PT, Phi, Eta, Dxy, Eem, Ehad
# [========            ] 421/999
